# %%
import pandas as pd

# %%
Dm=pd.read_csv(r'D:\intership\tested.csv')
Dm
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
Dm.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
Dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
print(Dm['PassengerId'].value_counts())
# Out:
# PassengerId
# 892     1
# 893     1
# 894     1
# 895     1
# 896     1
#        ..
# 1305    1
# 1306    1
# 1307    1
# 1308    1
# 1309    1
# Name: count, Length: 418, dtype: int64

# %%
Dm.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                     Sex     Age   SibSp  Parch  Ticket         Fare      Cabin            Embarked
# 904          1         1       Snyder, Mrs. John Pillsbury (Nelle Stevenson)            female  23.0  1      0      21228          82.2667   B45              S           1
# 906          1         1       Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)  female  47.0  1      0      W.E.P. 5734    61.1750   E31              S           1
# 916          1         1       Ryerson, Mrs. Arthur Larned (Emily Maria Borie)          female  48.0  1      3      PC 17608       262.3750  B57 B59 B63 B66  C           1
# 918          1         1       Ostby, Miss. Helene Ragnhild                             female  22.0  0      1      113509         61.9792   B36              C           1
# ...

# %%
print(Dm['Pclass'].value_counts())
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
print(Dm['Pclass'].value_counts(normalize=True))
# Out:
# Pclass
# 3    0.521531
# 1    0.255981
# 2    0.222488
# Name: proportion, dtype: float64

# %%
print(Dm['Sex'].value_counts())
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
print(Dm['Sex'].value_counts(normalize=True))
# Out:
# Sex
# male      0.636364
# female    0.363636
# Name: proportion, dtype: float64

# %%
print(Dm['Age'].value_counts())
# Out:
# Age
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 44.0     1
# 5.0      1
# 51.0     1
# 3.0      1
# 38.5     1
# Name: count, Length: 79, dtype: int64

# %%
print(Dm['Age'].value_counts(normalize=True))
# Out:
# Age
# 21.0    0.051205
# 24.0    0.051205
# 22.0    0.048193
# 30.0    0.045181
# 18.0    0.039157
#           ...
# 44.0    0.003012
# 5.0     0.003012
# 51.0    0.003012
# 3.0     0.003012
# 38.5    0.003012
# Name: proportion, Length: 79, dtype: float64

# %%
print(Dm['Name'].value_counts())
# Out:
# Name
# Kelly, Mr. James                                1
# Wilkes, Mrs. James (Ellen Needs)                1
# Myles, Mr. Thomas Francis                       1
# Wirz, Mr. Albert                                1
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1
#                                                ..
# Spector, Mr. Woolf                              1
# Oliva y Ocana, Dona. Fermina                    1
# Saether, Mr. Simon Sivertsen                    1
# Ware, Mr. Frederick                             1
# Peter, Master. Michael J                        1
# Name: count, Length: 418, dtype: int64

# %%
print(Dm['SibSp'].value_counts())
# Out:
# SibSp
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: count, dtype: int64

# %%
print(Dm['SibSp'].value_counts(normalize=True))
# Out:
# SibSp
# 0    0.677033
# 1    0.263158
# 2    0.033493
# 3    0.009569
# 4    0.009569
# 8    0.004785
# 5    0.002392
# Name: proportion, dtype: float64

# %%
print(Dm['Parch'].value_counts())
# Out:
# Parch
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: count, dtype: int64

# %%
print(Dm['Parch'].value_counts(normalize=True))
# Out:
# Parch
# 0    0.775120
# 1    0.124402
# 2    0.078947
# 3    0.007177
# 4    0.004785
# 9    0.004785
# 6    0.002392
# 5    0.002392
# Name: proportion, dtype: float64

# %%
print(Dm['Ticket'].value_counts())
# Out:
# Ticket
# PC 17608              5
# CA. 2343              4
# 113503                4
# 347077                3
# SOTON/O.Q. 3101315    3
#                      ..
# 330972                1
# 7538                  1
# 3101298               1
# 315154                1
# 240276                1
# Name: count, Length: 363, dtype: int64

# %%
print(Dm['Cabin'].value_counts())
# Out:
# Cabin
# B57 B59 B63 B66    3
# B45                2
# C23 C25 C27        2
# C78                2
# C31                2
#                   ..
# B41                1
# C7                 1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 76, dtype: int64

# %%
print(Dm['Embarked'].value_counts())
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(Dm)

# %%
sns.heatmap(Dm.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(Dm.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
pplot= ['Survived','Age', 'Fare', 'Parch']
sns.pairplot(Dm[pplot])

# %%
pplot= ['Survived','Age', 'Fare', 'Parch']
sns.pairplot(Dm[pplot].dropna(), hue='Survived', diag_kind='hist')

# %%
corr = Dm.select_dtypes(include=['float64', 'int64']).corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.histplot(data=Dm, x='Age', hue='Survived', bins=30, kde=True)
plt.title('Age Distribution by Survival Status')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Survival Status')

# %%
sns.histplot(data=Dm, x='Sex', hue='Survived', bins=30, kde=True)
plt.title('Sex Distribution by Survival Status')
# Out:
# Text(0.5, 1.0, 'Sex Distribution by Survival Status')

# %%
sns.boxplot(data=Dm, x='Age',y='Fare', hue='Survived', )
plt.title('Age Distribution by Survival Status')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Survival Status')

# %%
sns.scatterplot(data=Dm, x='Age',y='Fare', hue='Survived', )
plt.title('Age Distribution by Survival Status')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Survival Status')

# %%
sns.boxplot(data=Dm, x='Pclass', y='Age', hue='Survived')
plt.title('Age vs Passenger Class, Split by Survival')
# Out:
# Text(0.5, 1.0, 'Age vs Passenger Class, Split by Survival')

# %%
sns.scatterplot(data=Dm, x='Age', y='Fare', hue='Survived', alpha=0.6)
plt.title('Fare vs Age, Colored by Survival')
# Out:
# Text(0.5, 1.0, 'Fare vs Age, Colored by Survival')

# %%
sns.jointplot(data=Dm, x='Age', y='Fare', hue='Survived', kind='hist')
plt.suptitle('Joint Distribution of Age and Fare by Survival', y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Distribution of Age and Fare by Survival')

# %%
sns.jointplot(data=Dm, x='Age', y='Fare', hue='Survived', kind='kde')
plt.suptitle('Joint Distribution of Age and Fare by Survival', y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Distribution of Age and Fare by Survival')
